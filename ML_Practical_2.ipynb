# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhat1908/ml.xyz/blob/main/ML_Practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

st.title("KNN Weather Classification")

X = np.array(
    [
        [30,70], [25,80], [27,60],
        [31,65], [23,85], [28,75]
    ]
)
y = np.array([0,1,0,0,1,1])

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X,y)

temp = st.slider("Temperature",20,35,26)
humidity = st.slider("Humidity",50,90,78)

new_point = np.array([[temp,humidity]])
prediction = knn.predict(new_point)[0]

fig, ax = plt.subplots()
ax.scatter(X[y==0,0],X[y==0,1],label="Sunny")
ax.scatter(X[y==1,0],X[y==1,1],label="Rainy")
ax.scatter(temp,humidity,color="red",marker="*",s=200,label="New")
ax.legend()
st.pyplot(fig)

st.subheader("Prediction")
st.success("Sunny") if prediction==0 else st.info("Rainy")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.1
#     Uninstalling cachetools-7.0.1:
#       Successfully uninstalled cachetools-7.0.1
# ...
# 2026-02-18 00:45:23.142 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-18 00:45:23.362
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-02-18 00:45:23.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-18 00:45:23.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
